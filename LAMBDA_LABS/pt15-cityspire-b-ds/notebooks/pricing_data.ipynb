# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Zip_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_mon.csv')

# %%
pd.options.display.min_rows = 200
data.isnull().sum()
# Out:
# RegionID          0
# SizeRank          0
# RegionName        0
# RegionType        0
# StateName         0
# State             0
# City              0
# Metro          7108
# CountyName        0
# 1996-01-31    17054
# 1996-02-29    16813
# 1996-03-31    16774
# 1996-04-30    16754
# 1996-05-31    16671
# 1996-06-30    16637
# 1996-07-31    16615
# 1996-08-31    16580
# 1996-09-30    16559
# 1996-10-31    16537
# 1996-11-30    16516
# 1996-12-31    16487
# 1997-01-31    16370
# 1997-02-28    16324
# 1997-03-31    16263
# 1997-04-30    16212
# 1997-05-31    16182
# 1997-06-30    16161
# 1997-07-31    16141
# 1997-08-31    16094
# 1997-09-30    16045
#               ...
# 2018-07-31       76
# 2018-08-31       51
# 2018-09-30       35
# 2018-10-31       15
# 2018-11-30        0
# 2018-12-31        0
# 2019-01-31        0
# 2019-02-28        0
# 2019-03-31        0
# 2019-04-30        0
# 2019-05-31        0
# 2019-06-30        0
# 2019-07-31        0
# 2019-08-31        0
# ...

# %%
data.head(30)
# Out:
#     RegionID  SizeRank  RegionName RegionType StateName State           City  \
# 0      61639         0       10025        Zip        NY    NY       New York
# 1      84654         1       60657        Zip        IL    IL        Chicago
# 2      61637         2       10023        Zip        NY    NY       New York
# 3      91982         3       77494        Zip        TX    TX           Katy
# 4      84616         4       60614        Zip        IL    IL        Chicago
# 5      91940         5       77449        Zip        TX    TX           Katy
# 6      61616         6       10002        Zip        NY    NY       New York
# 7      91733         7       77084        Zip        TX    TX        Houston
# 8      93144         8       79936        Zip        TX    TX        El Paso
# 9      84640         9       60640        Zip        IL    IL        Chicago
# 10     62037        10       11226        Zip        NY    NY       New York
# ...

# %%
main = data.iloc[:, 0:9]

# %%
type(main['Metro'])
# Out:
# pandas.core.series.Series

# %%
main['Metro'] = main['Metro'].replace(np.nan, 'None')

# %%
prices = data.iloc[:, -48:]

# %%
prices[prices['2017-01-31'].isnull() == True]
# Out:
#        2017-01-31  2017-02-28  2017-03-31  2017-04-30  2017-05-31  2017-06-30  \
# 1722          NaN         NaN         NaN         NaN         NaN         NaN
# 3255          NaN         NaN         NaN         NaN    166941.0    167572.0
# 3631          NaN         NaN         NaN         NaN         NaN         NaN
# 3770          NaN         NaN         NaN         NaN         NaN         NaN
# 4278          NaN         NaN         NaN         NaN    149888.0    150397.0
# 4487          NaN         NaN         NaN         NaN         NaN         NaN
# 5149          NaN         NaN         NaN         NaN         NaN         NaN
# 5242          NaN         NaN     21791.0     21781.0     21841.0     22008.0
# 6512          NaN         NaN         NaN         NaN         NaN         NaN
# 6563          NaN         NaN         NaN         NaN         NaN         NaN
# 7133          NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
rent_data = pd.concat([main, prices], axis=1)

# %%
rent_data
# Out:
#       NY    NY
# 1         84654         1       60657        Zip        IL    IL
# 2         61637         2       10023        Zip        NY    NY
# 3         91982         3       77494        Zip        TX    TX
# 4         84616         4       60614        Zip        IL    IL
# 5         91940         5       77449        Zip        TX    TX
# 6         61616         6       10002        Zip        NY    NY
# 7         91733         7       77084        Zip        TX    TX
# 8         93144         8       79936        Zip        TX    TX
# 9         84640         9       60640        Zip        IL    IL
# 10        62037        10       11226        Zip        NY    NY
# 11        61807        11       10467        Zip        NY    NY
# 12        92593        12       78660        Zip        TX    TX
# 13        97564        13       94109        Zip        CA    CA
# 14        61630        15       10016        Zip        NY    NY
# ...

# %%
from IPython.display import FileLink, FileLinks

# %%
rent_data.to_csv('rental_data.csv', index=False)

FileLinks()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-3a944184f0c5> in <module>
#       1 rent_data.to_csv('rental_data.csv', index=False)
#       2
# ----> 3 FileLinks()
#
# TypeError: __init__() missing 1 required positional argument: 'path'

# %%
rent_data.info
# Out:
#      NY    NY
# 1         84654         1       60657        Zip        IL    IL
# 2         61637         2       10023        Zip        NY    NY
# 3         91982         3       77494        Zip        TX    TX
# 4         84616         4       60614        Zip        IL    IL
# 5         91940         5       77449        Zip        TX    TX
# 6         61616         6       10002        Zip        NY    NY
# 7         91733         7       77084        Zip        TX    TX
# 8         93144         8       79936        Zip        TX    TX
# 9         84640         9       60640        Zip        IL    IL
# 10        62037        10       11226        Zip        NY    NY
# 11        61807        11       10467        Zip        NY    NY
# 12        92593        12       78660        Zip        TX    TX
# 13        97564        13       94109        Zip        CA    CA
# 14        61630        15       10016        Zip        NY    NY
# ...

# %%
import psycopg2
import sys
import boto3

ENDPOINT = "db-test-inovak4.c2uishzxxikl.us-east-1.rds.amazonaws.com"
PORT = "5432"
USR = 'dell4'
REGION = 'us-east-1'
DBNAME = 'cityspire'

session = boto3.Session(profile_name='RDSCreds')
client = boto3.client('rds')

token = client.generate_db_auth_token(DBHostname=ENDPOINT, Port=PORT, DBUsername=USR, Region=REGION)

password='6hB1iSYrtR'
try:
    conn = psycopg2.connect(host=ENDPOINT, port=PORT, database=DBNAME, user=USR, password=password)
    cur = conn.cursor()
    cur.copy_from()

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://dell4:6hB1iSYrtR@db-test-inovak4.c2uishzxxikl.us-east-1.rds.amazonaws.com:5432/cityspire')
rent_data.to_sql('rental_rates', engine)
